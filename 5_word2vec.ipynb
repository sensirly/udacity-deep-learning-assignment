# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156, 128, 742, 477, 10572, 134, 1, 27350, 2, 1, 103, 855, 3, 1, 15068, 0, 2, 1, 151, 855, 3581, 1, 195, 11, 191, 59, 5, 6, 10713, 215, 7, 1325, 105, 455, 20, 59, 2732, 363, 7, 3673, 1, 709, 2, 372, 27, 41, 37, 54, 540, 98, 12, 6, 1424, 2758, 19, 568, 687, 7089, 1, 248, 5234, 11, 1053, 28, 1, 321, 249, 44612, 2878, 793, 187, 5234, 12, 6, 201, 603, 11, 1, 1135, 20, 2622, 26, 8984, 3, 280, 32, 4148, 142, 60, 26, 6438]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 5 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.033866
# Nearest to first: magnificence, scan, nucleosome, malraux, roundel,
# Nearest to would: alkenes, depth, bmc, mystic, unverifiable,
# Nearest to that: teutoburg, skinner, profiles, amedeo, turnaround,
# Nearest to four: thrice, englishman, foundationalism, perched, puncture,
# Nearest to or: volk, greater, actions, christos, canvas,
# Nearest to not: aggadah, musical, hinted, bully, ration,
# Nearest to people: celery, linden, zaire, kites, lavoisier,
# Nearest to use: singhasari, sickle, jordanian, durians, quadratic,
# Nearest to their: ganga, mayen, signer, argentina, contributed,
# Nearest to zero: castiglione, gridiron, rhetoric, euboea, oligarchy,
# Nearest to is: fiesole, lam, sister, atlanteans, fishermen,
# Nearest to there: kirkwood, discreetly, mercenary, stratum, acker,
# Nearest to eight: alberts, tint, hospitalized, enumerates, collect,
# Nearest to only: uss, rob, fiorentina, likelihood, commonwealth,
# Nearest to for: totalitarian, underwing, initialism, unsubstantiated, boxes,
# Nearest to nine: jonas, studs, gothenburg, intranet, endowment,
# Average loss at step 2000: 4.360900
# Average loss at step 4000: 3.829152
# Average loss at step 6000: 3.788885
# Average loss at step 8000: 3.671938
# Average loss at step 10000: 3.573307
# Nearest to first: jes, golems, own, prd, magnificence,
# Nearest to would: may, can, could, depth, pickwick,
# Nearest to that: which, however, bahamas, gibbs, turnaround,
# Nearest to four: eight, seven, six, five, nine,
# Nearest to or: and, adenosine, s, the, peking,
# Nearest to not: never, it, already, bully, nanotubes,
# Nearest to people: linden, microinstruction, celery, spitzer, hmos,
# Nearest to use: singhasari, placeholder, possession, cherries, ireland,
# Nearest to their: his, its, the, floors, peregrine,
# Nearest to zero: five, six, nine, seven, eight,
# Nearest to is: was, are, has, yap, were,
# Nearest to there: it, they, gangetic, foreground, boast,
# Nearest to eight: nine, six, seven, four, five,
# Nearest to only: uss, commonwealth, cassady, apc, bow,
# Nearest to for: yourdon, with, in, overdue, at,
# Nearest to nine: eight, six, seven, five, four,
# Average loss at step 12000: 3.470259
# Average loss at step 14000: 3.551646
# Average loss at step 16000: 3.581922
# Average loss at step 18000: 3.528517
# Average loss at step 20000: 3.505373
# Nearest to first: next, jes, golems, prd, maximus,
# Nearest to would: could, may, can, will, should,
# Nearest to that: which, this, however, duran, bahamas,
# Nearest to four: six, seven, eight, three, five,
# Nearest to or: and, hardwired, herein, scots, peking,
# Nearest to not: never, already, still, it, often,
# Nearest to people: others, bloomberg, hmos, years, men,
# Nearest to use: possession, placeholder, gulliver, support, singhasari,
# Nearest to their: its, his, her, some, peregrine,
# Nearest to zero: six, eight, seven, four, nine,
# Nearest to is: was, has, are, conciliation, yap,
# Nearest to there: it, they, he, which, now,
# Nearest to eight: seven, nine, six, four, three,
# Nearest to only: commonwealth, never, uss, bow, microcomputer,
# Nearest to for: at, with, reacting, kendall, yourdon,
# Nearest to nine: eight, seven, six, four, three,
# Average loss at step 22000: 3.532836
# Average loss at step 24000: 3.470173
# Average loss at step 26000: 3.550720
# Average loss at step 28000: 3.506640
# Average loss at step 30000: 3.522137
# Nearest to first: second, next, last, same, rahilly,
# Nearest to would: could, can, may, will, might,
# Nearest to that: which, but, willy, gibbs, this,
# Nearest to four: five, six, three, seven, eight,
# Nearest to or: and, than, magnetron, souvenirs, spokes,
# Nearest to not: it, already, never, still, they,
# Nearest to people: others, frontiers, offsets, mastery, linden,
# Nearest to use: possession, support, sense, placeholder, cherries,
# Nearest to their: its, his, her, peregrine, the,
# Nearest to zero: five, seven, six, four, eight,
# Nearest to is: was, has, are, became, were,
# Nearest to there: they, it, he, now, often,
# Nearest to eight: seven, six, nine, three, four,
# Nearest to only: apc, augusta, never, uss, maffei,
# Nearest to for: after, against, with, yourdon, conclave,
# Nearest to nine: seven, eight, six, three, five,
# Average loss at step 32000: 3.420415
# Average loss at step 34000: 3.380213
# Average loss at step 36000: 3.463612
# Average loss at step 38000: 3.439037
# Average loss at step 40000: 3.459978
# Nearest to first: second, last, next, mediate, indivisible,
# Nearest to would: will, could, can, may, might,
# Nearest to that: which, however, but, this, bahamas,
# Nearest to four: seven, eight, six, three, five,
# Nearest to or: and, than, spokes, barren, anaximander,
# Nearest to not: never, already, they, also, there,
# Nearest to people: others, men, offsets, mastery, frontiers,
# Nearest to use: sense, possession, end, relic, support,
# Nearest to their: its, his, her, the, peregrine,
# Nearest to zero: eight, five, six, seven, four,
# Nearest to is: was, are, has, be, rial,
# Nearest to there: they, it, he, now, still,
# Nearest to eight: nine, six, seven, four, three,
# Nearest to only: multimedia, propriety, swallow, hom, articulate,
# Nearest to for: in, against, conclave, after, yourdon,
# Nearest to nine: eight, seven, six, four, three,
# Average loss at step 42000: 3.445469
# Average loss at step 44000: 3.373388
# Average loss at step 46000: 3.397454
# Average loss at step 48000: 3.451500
# Average loss at step 50000: 3.446883
# Nearest to first: second, next, last, indivisible, same,
# Nearest to would: will, could, can, may, might,
# Nearest to that: which, however, what, squash, bahamas,
# Nearest to four: six, eight, five, seven, three,
# Nearest to or: and, than, centrale, manufacturing, gracie,
# Nearest to not: never, popularly, almost, they, still,
# Nearest to people: others, men, members, those, mastery,
# Nearest to use: sense, end, accommodate, placeholder, possession,
# Nearest to their: its, his, her, the, some,
# Nearest to zero: six, eight, seven, five, four,
# Nearest to is: was, are, has, makes, be,
# Nearest to there: they, it, he, now, still,
# Nearest to eight: six, nine, seven, four, five,
# Nearest to only: augusta, dani, never, swallow, hassan,
# Nearest to for: after, yourdon, to, against, cookbooks,
# Nearest to nine: eight, six, seven, four, five,
# Average loss at step 52000: 3.432898
# Average loss at step 54000: 3.406552
# Average loss at step 56000: 3.411765
# Average loss at step 58000: 3.169642
# Average loss at step 60000: 3.356916
# Nearest to first: second, last, next, indivisible, hangover,
# Nearest to would: will, could, can, may, might,
# Nearest to that: which, however, duran, what, this,
# Nearest to four: six, five, eight, seven, three,
# Nearest to or: and, anaximander, emotionally, but, souvenirs,
# Nearest to not: popularly, now, still, they, never,
# Nearest to people: others, men, members, publication, sources,
# Nearest to use: sense, possession, support, end, believe,
# Nearest to their: its, his, her, the, whose,
# Nearest to zero: eight, five, six, four, nine,
# Nearest to is: was, are, has, be, became,
# Nearest to there: they, it, now, still, he,
# Nearest to eight: six, nine, five, seven, four,
# Nearest to only: swallow, not, just, within, iau,
# Nearest to for: conclave, massif, of, when, if,
# Nearest to nine: eight, seven, six, five, four,
# Average loss at step 62000: 3.418857
# Average loss at step 64000: 3.376417
# Average loss at step 66000: 3.377628
# Average loss at step 68000: 3.372320
# Average loss at step 70000: 3.380783
# Nearest to first: second, last, next, third, indivisible,
# Nearest to would: will, could, might, may, can,
# Nearest to that: which, however, what, amedeo, where,
# Nearest to four: five, six, three, seven, eight,
# Nearest to or: and, than, emotionally, like, thugs,
# Nearest to not: now, still, popularly, almost, generally,
# Nearest to people: men, others, members, those, countries,
# Nearest to use: sense, support, believe, isfahan, engendered,
# Nearest to their: its, his, her, your, the,
# Nearest to zero: eight, six, seven, five, nine,
# Nearest to is: was, are, has, be, became,
# Nearest to there: they, it, he, now, still,
# Nearest to eight: nine, seven, six, five, four,
# Nearest to only: swallow, yet, first, iau, chime,
# Nearest to for: including, yourdon, electoral, minos, debtors,
# Nearest to nine: eight, seven, six, five, four,
# Average loss at step 72000: 3.311130
# Average loss at step 74000: 3.345965
# Average loss at step 76000: 3.401734
# Average loss at step 78000: 3.414946
# Average loss at step 80000: 3.408153
# Nearest to first: second, last, next, third, faunal,
# Nearest to would: could, will, might, may, can,
# Nearest to that: which, however, what, where, amedeo,
# Nearest to four: five, seven, three, eight, six,
# Nearest to or: and, gob, convolutions, than, franca,
# Nearest to not: now, still, almost, popularly, nor,
# Nearest to people: men, others, members, those, countries,
# Nearest to use: sense, support, way, accommodate, presence,
# Nearest to their: its, his, her, your, the,
# Nearest to zero: five, seven, eight, six, four,
# Nearest to is: was, has, are, be, became,
# Nearest to there: they, it, he, now, we,
# Nearest to eight: seven, five, nine, six, three,
# Nearest to only: iau, either, swallow, correspondence, best,
# Nearest to for: debtors, after, without, yourdon, perverted,
# Nearest to nine: seven, eight, five, six, three,
# Average loss at step 82000: 3.377731
# Average loss at step 84000: 3.367660
# Average loss at step 86000: 3.368997
# Average loss at step 88000: 3.382339
# Average loss at step 90000: 3.284799
# Nearest to first: last, second, next, indivisible, mediate,
# Nearest to would: could, will, might, can, may,
# Nearest to that: which, however, what, but, seventies,
# Nearest to four: six, five, seven, eight, three,
# Nearest to or: and, than, spokes, any, magnetron,
# Nearest to not: still, popularly, now, nor, generally,
# Nearest to people: men, others, members, players, cotangent,
# Nearest to use: sense, romantics, because, way, measure,
# Nearest to their: its, his, her, your, our,
# Nearest to zero: seven, five, six, eight, four,
# Nearest to is: was, has, are, became, although,
# Nearest to there: they, it, we, now, he,
# Nearest to eight: seven, six, nine, four, five,
# Nearest to only: iau, either, articulate, typesetting, swallow,
# Nearest to for: including, after, debtors, yourdon, while,
# Nearest to nine: seven, eight, six, five, three,
# Average loss at step 92000: 3.336080
# Average loss at step 94000: 3.246251
# Average loss at step 96000: 3.364958
# Average loss at step 98000: 3.321381
# Average loss at step 100000: 3.318992
# Nearest to first: last, second, next, third, fourth,
# Nearest to would: could, will, might, can, should,
# Nearest to that: which, however, what, about, hydras,
# Nearest to four: six, seven, five, eight, three,
# Nearest to or: and, than, though, spokes, venera,
# Nearest to not: nor, popularly, still, almost, now,
# Nearest to people: men, others, members, those, americans,
# Nearest to use: sense, consumed, measure, accommodate, cause,
# Nearest to their: its, his, her, your, our,
# Nearest to zero: five, seven, four, six, eight,
# Nearest to is: was, has, became, are, does,
# Nearest to there: they, it, he, we, now,
# Nearest to eight: nine, seven, six, four, five,
# Nearest to only: iau, either, otherwise, just, articulate,
# Nearest to for: after, in, yourdon, without, debtors,
# Nearest to nine: eight, seven, six, five, four,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(20,20))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def cbow_batch(batch_size, bag_window):
  global data_index
  batch = np.ndarray(shape=(batch_size,bag_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    batch[i] = list(buffer)[:bag_window] + list(buffer)[bag_window+1:]
    labels[i] = buffer[bag_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:12]])

batch, labels = cbow_batch(8,1)
print('batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
print('labels:', [reverse_dictionary[l] for l in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
# batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
# labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = cbow_batch(batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 5 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.125739
# Nearest to at: apse, endure, onager, eminently, treat,
# Nearest to between: uber, aspired, comparisons, dalit, toothpaste,
# Nearest to d: versatility, ph, yields, hatton, configurable,
# Nearest to five: curiosities, hamsun, hangman, manar, chessboard,
# Nearest to its: optimum, szczecin, missile, harvester, aiki,
# Nearest to be: phoenician, atlanta, bestiary, nikaya, dilation,
# Nearest to is: technologies, angiosperms, corned, detector, hellenic,
# Nearest to new: mongolians, audrey, gelatinous, geography, flourishes,
# Nearest to after: relates, wien, ishikawa, paolo, dogmatically,
# Nearest to american: kio, gmt, concerts, plasmas, rene,
# Nearest to from: fluffy, interlocking, anabaptist, imaginative, subclasses,
# Nearest to they: outsiders, rulemaking, volleys, headway, qualitatively,
# Nearest to been: standardised, logographic, weaning, saloons, knobs,
# Nearest to people: aortic, morel, sins, desires, sanger,
# Nearest to so: eucharistic, worcestershire, solstice, samuelson, holst,
# Nearest to not: compelled, bronx, sigmund, defoe, spades,
# Average loss at step 2000: 4.090275
# Average loss at step 4000: 3.559167
# Average loss at step 6000: 3.386044
# Average loss at step 8000: 3.240962
# Average loss at step 10000: 3.173537
# Nearest to at: in, hussain, crusader, flamboyant, yahoo,
# Nearest to between: through, in, principality, into, with,
# Nearest to d: b, herpes, versatility, psychoanalysis, longhorn,
# Nearest to five: four, six, seven, eight, nine,
# Nearest to its: their, his, the, her, compiler,
# Nearest to be: been, have, were, leaning, become,
# Nearest to is: was, has, are, became, be,
# Nearest to new: flourishes, geography, progenitors, mongolians, flung,
# Nearest to after: before, during, transliterated, seth, acronym,
# Nearest to american: austrian, diels, russian, eriksson, strident,
# Nearest to from: into, flashpoint, among, raucous, in,
# Nearest to they: he, we, there, she, it,
# Nearest to been: be, bilateral, bets, were, become,
# Nearest to people: fortunate, isosceles, baen, bunsen, things,
# Nearest to so: worcestershire, disputes, departing, lombards, evicted,
# Nearest to not: prescribed, pronounces, also, promise, compelled,
# Average loss at step 12000: 3.203967
# Average loss at step 14000: 3.150680
# Average loss at step 16000: 3.178245
# Average loss at step 18000: 3.126491
# Average loss at step 20000: 2.987379
# Nearest to at: in, during, crusader, hussain, constans,
# Nearest to between: through, with, into, banda, flashpoint,
# Nearest to d: b, versatility, superconducting, herpes, sacrificed,
# Nearest to five: six, seven, eight, four, three,
# Nearest to its: their, his, her, the, ignatius,
# Nearest to be: been, have, become, refer, lead,
# Nearest to is: was, has, are, became, indie,
# Nearest to new: flourishes, traditional, territorial, bulldog, few,
# Nearest to after: before, when, during, acronym, impure,
# Nearest to american: austrian, russian, english, australian, weezer,
# Nearest to from: into, among, talkin, flashpoint, raucous,
# Nearest to they: we, there, he, you, she,
# Nearest to been: become, be, was, bets, etiquette,
# Nearest to people: fortunate, men, things, children, isosceles,
# Nearest to so: evicted, very, lombards, billion, azariah,
# Nearest to not: generally, prescribed, pronounces, never, promise,
# Average loss at step 22000: 3.075394
# Average loss at step 24000: 3.036862
# Average loss at step 26000: 3.000808
# Average loss at step 28000: 3.024653
# Average loss at step 30000: 3.001956
# Nearest to at: during, in, crusader, overturning, hussain,
# Nearest to between: with, within, through, among, in,
# Nearest to d: b, char, sdtv, versatility, yields,
# Nearest to five: four, six, seven, eight, nine,
# Nearest to its: their, his, her, the, ignatius,
# Nearest to be: been, being, refer, have, become,
# Nearest to is: was, has, are, does, became,
# Nearest to new: flourishes, traditional, manufactures, langevin, wacky,
# Nearest to after: before, during, when, through, under,
# Nearest to american: austrian, russian, european, australian, german,
# Nearest to from: into, through, wahhabism, under, fluffy,
# Nearest to they: we, there, he, you, she,
# Nearest to been: become, be, were, etiquette, nike,
# Nearest to people: fortunate, men, things, children, others,
# Nearest to so: evicted, bone, bai, very, sibm,
# Nearest to not: never, pronounces, generally, now, opanal,
# Average loss at step 32000: 2.827543
# Average loss at step 34000: 2.957749
# Average loss at step 36000: 2.944833
# Average loss at step 38000: 2.939766
# Average loss at step 40000: 2.934823
# Nearest to at: overturning, crusader, during, around, endure,
# Nearest to between: within, among, with, through, millicent,
# Nearest to d: b, char, configurable, transpose, polymerase,
# Nearest to five: six, four, seven, eight, three,
# Nearest to its: their, his, her, the, your,
# Nearest to be: been, become, being, have, refer,
# Nearest to is: was, has, be, became, are,
# Nearest to new: flourishes, coalition, finno, manufactures, wacky,
# Nearest to after: before, during, when, despite, while,
# Nearest to american: austrian, russian, australian, italian, british,
# Nearest to from: into, through, in, during, puppy,
# Nearest to they: we, you, he, there, she,
# Nearest to been: become, be, was, nike, were,
# Nearest to people: men, children, things, others, jews,
# Nearest to so: evicted, teaches, thus, bai, graft,
# Nearest to not: pronounces, opanal, prescribed, usually, dynamo,
# Average loss at step 42000: 2.954624
# Average loss at step 44000: 2.958941
# Average loss at step 46000: 2.910769
# Average loss at step 48000: 2.861962
# Average loss at step 50000: 2.852297
# Nearest to at: during, in, around, crusader, hussain,
# Nearest to between: within, among, with, through, concerning,
# Nearest to d: b, bullet, rearden, fadh, vj,
# Nearest to five: four, six, seven, eight, three,
# Nearest to its: their, his, the, her, your,
# Nearest to be: been, become, have, refer, is,
# Nearest to is: was, has, are, became, be,
# Nearest to new: capoeiristas, flourishes, coalition, unsophisticated, manufactures,
# Nearest to after: before, during, when, despite, while,
# Nearest to american: austrian, british, italian, australian, french,
# Nearest to from: into, through, in, during, at,
# Nearest to they: we, there, he, you, she,
# Nearest to been: become, be, was, already, recently,
# Nearest to people: children, men, fortunate, women, jews,
# Nearest to so: teaches, thus, evicted, graft, aac,
# Nearest to not: still, never, prescribed, now, nor,
# Average loss at step 52000: 2.887146
# Average loss at step 54000: 2.860356
# Average loss at step 56000: 2.863872
# Average loss at step 58000: 2.750506
# Average loss at step 60000: 2.835514
# Nearest to at: during, in, under, crusader, throughout,
# Nearest to between: among, within, with, through, shattering,
# Nearest to d: b, rearden, char, bloomberg, transpose,
# Nearest to five: seven, four, six, eight, nine,
# Nearest to its: their, his, the, her, whose,
# Nearest to be: been, become, being, have, is,
# Nearest to is: was, has, are, becomes, refers,
# Nearest to new: flourishes, coalition, manufactures, different, cgs,
# Nearest to after: before, during, when, despite, while,
# Nearest to american: italian, australian, austrian, german, french,
# Nearest to from: into, through, wahhabism, before, by,
# Nearest to they: we, you, he, there, she,
# Nearest to been: be, become, already, grown, were,
# Nearest to people: men, children, women, others, person,
# Nearest to so: thus, teaches, too, evicted, aac,
# Nearest to not: never, usually, prescribed, nor, actually,
# Average loss at step 62000: 2.834356
# Average loss at step 64000: 2.770393
# Average loss at step 66000: 2.763856
# Average loss at step 68000: 2.712110
# Average loss at step 70000: 2.786057
# Nearest to at: near, crusader, during, in, endure,
# Nearest to between: within, among, with, dispel, following,
# Nearest to d: b, rearden, transpose, emissaries, sacrificed,
# Nearest to five: six, seven, nine, eight, four,
# Nearest to its: their, his, the, her, whose,
# Nearest to be: been, become, have, being, refer,
# Nearest to is: was, has, are, remains, contains,
# Nearest to new: flourishes, socialist, different, provisional, traditional,
# Nearest to after: before, during, when, despite, while,
# Nearest to american: australian, austrian, italian, british, english,
# Nearest to from: through, under, into, fluffy, between,
# Nearest to they: we, he, you, there, she,
# Nearest to been: become, be, grown, was, nike,
# Nearest to people: men, children, women, person, players,
# Nearest to so: thus, teaches, too, evicted, sometimes,
# Nearest to not: never, now, actually, always, still,
# Average loss at step 72000: 2.798867
# Average loss at step 74000: 2.645877
# Average loss at step 76000: 2.803266
# Average loss at step 78000: 2.830083
# Average loss at step 80000: 2.782826
# Nearest to at: during, in, crusader, near, around,
# Nearest to between: among, within, with, battleships, ebu,
# Nearest to d: b, sdtv, emissaries, c, char,
# Nearest to five: six, seven, eight, four, three,
# Nearest to its: their, his, her, whose, the,
# Nearest to be: become, been, refer, is, undergo,
# Nearest to is: was, contains, has, remains, are,
# Nearest to new: flourishes, progenitors, different, coalition, wacky,
# Nearest to after: before, during, when, despite, while,
# Nearest to american: italian, australian, austrian, german, french,
# Nearest to from: into, through, within, wahhabism, fluffy,
# Nearest to they: we, you, he, she, there,
# Nearest to been: become, be, grown, remained, were,
# Nearest to people: men, children, women, jews, persons,
# Nearest to so: too, teaches, extremely, thus, how,
# Nearest to not: almost, never, actually, still, prescribed,
# Average loss at step 82000: 2.669227
# Average loss at step 84000: 2.775479
# Average loss at step 86000: 2.729175
# Average loss at step 88000: 2.753969
# Average loss at step 90000: 2.735738
# Nearest to at: during, near, in, crusader, overturning,
# Nearest to between: among, within, with, slowest, across,
# Nearest to d: b, emissaries, char, sdtv, memos,
# Nearest to five: six, four, seven, eight, three,
# Nearest to its: their, his, the, whose, her,
# Nearest to be: become, been, being, refer, remain,
# Nearest to is: was, has, contains, remains, are,
# Nearest to new: manufactures, coalition, wacky, unsophisticated, progenitors,
# Nearest to after: before, during, when, despite, though,
# Nearest to american: italian, australian, african, austrian, french,
# Nearest to from: through, into, across, in, during,
# Nearest to they: we, you, he, she, there,
# Nearest to been: become, be, remained, grown, gelatinous,
# Nearest to people: women, men, children, persons, jews,
# Nearest to so: too, teaches, sometimes, evicted, insisted,
# Nearest to not: never, nor, actually, now, almost,
# Average loss at step 92000: 2.680984
# Average loss at step 94000: 2.725341
# Average loss at step 96000: 2.705474
# Average loss at step 98000: 2.365228
# Average loss at step 100000: 2.398158
# Nearest to at: during, in, near, crusader, on,
# Nearest to between: within, with, among, concerning, erin,
# Nearest to d: b, fresno, noxious, tomasz, emissaries,
# Nearest to five: seven, four, six, eight, nine,
# Nearest to its: their, his, her, whose, your,
# Nearest to be: become, been, remain, adhere, have,
# Nearest to is: was, has, remains, became, are,
# Nearest to new: flourishes, separate, manufactures, cgs, particular,
# Nearest to after: before, during, when, despite, following,
# Nearest to american: english, australian, british, austrian, canadian,
# Nearest to from: across, through, under, into, fluffy,
# Nearest to they: we, he, you, there, she,
# Nearest to been: become, be, gelatinous, remained, grown,
# Nearest to people: men, women, children, man, persons,
# Nearest to so: too, thus, teaches, sometimes, evicted,
# Nearest to not: never, nor, now, dynamo, actually,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(20,20))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
